# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("zuu crew scores.csv")
df.head()
# Out:
#                        MemberName  EducationLevel  Attendance  TotalHours  \
# 0           Theekshana Rathnayake               3        79.9        43.7
# 1  Mayura Sandakalum Sellapperuma               2        76.8        95.6
# 2                 Amila Narangoda               3        96.6        75.9
# 3                    Nisal Gamage               1        74.5        63.9
# 4                Tharusha Vihanga               2        83.2        24.0
#
#    AssignmentsCompleted  HackathonParticipation  GitHubScore  PeerReviewScore  \
# 0                     2                       0         62.8              5.0
# 1                     6                       0         87.4              2.7
# 2                     8                       0         98.4              2.8
# 3                     7                       0         76.8              1.7
# 4                     6                       0         41.8              4.2
#
#                     CourseName  CapstoneScore
# 0            Foundations of ML           45.3
# 1            Foundations of ML           78.8
# 2            Foundations of ML           65.4
# 3  Production-Ready ML Systems          100.0
# 4            Foundations of ML           40.1

# %%
df = df[df['CourseName'] == 'Foundations of ML']
df.head()
# Out:
#                        MemberName  EducationLevel  Attendance  TotalHours  \
# 0           Theekshana Rathnayake               3        79.9        43.7
# 1  Mayura Sandakalum Sellapperuma               2        76.8        95.6
# 2                 Amila Narangoda               3        96.6        75.9
# 4                Tharusha Vihanga               2        83.2        24.0
# 7                  Chamath Perera               3        86.5        88.0
#
#    AssignmentsCompleted  HackathonParticipation  GitHubScore  PeerReviewScore  \
# 0                     2                       0         62.8              5.0
# 1                     6                       0         87.4              2.7
# 2                     8                       0         98.4              2.8
# 4                     6                       0         41.8              4.2
# 7                     5                       0         23.9              1.3
#
#           CourseName  CapstoneScore
# 0  Foundations of ML           45.3
# 1  Foundations of ML           78.8
# 2  Foundations of ML           65.4
# 4  Foundations of ML           40.1
# 7  Foundations of ML           68.2

# %%
X = df['TotalHours'].values.reshape(-1, 1)
Y = df['CapstoneScore'].values

# %%
plt.figure(figsize=(10,6))
plt.scatter(X, Y, alpha=0.7, color='blue', s=50)
plt.xlabel('GitHubScore')
plt.ylabel('CapstoneScore')
plt.title('GitHubScore vs CapstoneScore')
plt.show()

# %%
def compute_cost(X, Y, beta):
    m = len(Y)
    y_hat = X.dot(beta)
    cost = (1/(2*m)) * np.sum((y_hat - Y) ** 2)

    return cost

# %%
X_with_bias = np.column_stack([np.ones((len(X))), X])
X_with_bias
# Out:
# array([[ 1. , 43.7],
#        [ 1. , 95.6],
#        [ 1. , 75.9],
#        [ 1. , 24. ],
#        [ 1. , 88. ],
#        [ 1. , 97.3],
#        [ 1. , 26.5],
#        [ 1. , 57.2],
#        [ 1. , 48.9],
#        [ 1. , 36.2],
#        [ 1. , 65.1],
#        [ 1. , 22.6],
#        [ 1. , 36.3],
#        [ 1. , 51. ],
#        [ 1. , 56.3],
#        [ 1. , 15.9],
#        [ 1. , 96.9],
#        [ 1. , 18.8],
#        [ 1. , 54.6],
#        [ 1. , 91.8],
#        [ 1. , 69.6],
#        [ 1. , 38.1],
#        [ 1. , 26.6],
#        [ 1. , 97.3],
#        [ 1. , 94.6],
#        [ 1. , 27.6],
#        [ 1. , 39.3],
#        [ 1. , 34.4],
#        [ 1. , 42.1],
#        [ 1. , 35.3],
#        [ 1. , 98.8],
#        [ 1. , 27.9],
#        [ 1. , 10.5],
#        [ 1. , 73.6],
#        [ 1. , 75.6],
#        [ 1. , 79.4],
#        [ 1. , 16.7],
#        [ 1. , 39.8],
#        [ 1. , 15.7],
#        [ 1. , 67.4],
#        [ 1. , 74.2],
#        [ 1. , 78.5],
#        [ 1. , 60.5],
#        [ 1. , 79.4],
#        [ 1. , 54.4],
#        [ 1. , 57. ],
#        [ 1. , 48.5],
#        [ 1. , 12.3],
#        [ 1. , 67.3],
#        [ 1. , 38.3],
#        [ 1. , 91.7],
#        [ 1. , 32.4],
#        [ 1. , 46.9],
#        [ 1. , 93.7],
#        [ 1. , 67. ],
#        [ 1. , 88.4],
#        [ 1. , 90.3],
#        [ 1. , 58.5],
#        [ 1. , 82.7],
#        [ 1. , 83.6],
#        [ 1. , 10.6],
#        [ 1. , 56. ],
#        [ 1. , 47.6],
#        [ 1. , 94.9],
#        [ 1. , 39.1],
#        [ 1. , 56.7],
#        [ 1. , 73.3],
#        [ 1. , 42.7],
#        [ 1. , 97.5],
#        [ 1. , 35.6],
#        [ 1. , 13.3],
#        [ 1. , 55.2]])

# %%
beta = np.random.randn(2)
print(f"Initial beta parameters: {beta}")
# Out:
# Initial beta parameters: [-1.09993264 -0.86935939]

# %%
y_hat = X_with_bias.dot(beta)
y_hat
# Out:
# array([-39.09093793, -84.2106902 , -67.08431024, -21.96455797,
#        -77.60355884, -85.68860116, -24.13795644, -50.82728967,
#        -43.61160675, -32.57074251, -57.69522884, -20.74745483,
#        -32.65767845, -45.43726146, -50.04486622, -14.92274692,
#        -85.3408574 , -17.44388915, -48.56695526, -80.90712452,
#        -61.60734609, -34.22252535, -24.22489238, -85.68860116,
#        -83.34133081, -25.09425177, -35.26575662, -31.00589561,
#        -37.69996291, -31.78831906, -86.99264024, -25.35505959,
#        -10.22820623, -65.08478365, -66.82350242, -70.1270681 ,
#        -15.61823443, -35.70043631, -14.74887505, -59.69475544,
#        -65.60639928, -69.34464465, -53.69617566, -70.1270681 ,
#        -48.39308339, -50.6534178 , -43.26386299, -11.79305312,
#        -59.6078195 , -34.39639723, -80.82018858, -29.26717684,
#        -41.87288797, -82.55890736, -59.34701168, -77.9513026 ,
#        -79.60308544, -51.95745688, -72.99595408, -73.77837753,
#        -10.31514216, -49.78405841, -42.48143954, -83.60213862,
#        -35.09188474, -50.39260998, -64.82397583, -38.22157854,
#        -85.86247304, -32.04912688, -12.66241251, -49.0885709 ])

# %%
cost = compute_cost(X_with_bias, Y, beta)
print("Initial Cost:", cost)
# Out:
# Initial Cost: 6290.8012725016015

# %%
def gradient_descent(X, Y, beta, lr, n_iter):
    m = len(Y)
    cost_history = []

    for i in range(n_iter):
        y_hat = X.dot(beta)

        gradients = (1 / m) * X.T.dot(y_hat - Y)

        beta = beta - lr * gradients

        cost = compute_cost(X, Y, beta)
        cost_history.append(cost)

        if i % 1000 == 0:
            print(f"Iteration : {i}, Cost: {cost:.4f}")

    return beta, cost_history

# %%
lr = 0.00001
n_iter = 10000

beta, cost_history = gradient_descent(X_with_bias, Y, beta, lr, n_iter)
# Out:
# Iteration : 0, Cost: 5819.9874
# Iteration : 1000, Cost: 55.8195
# Iteration : 2000, Cost: 55.6623
# Iteration : 3000, Cost: 55.5057
# Iteration : 4000, Cost: 55.3496
# Iteration : 5000, Cost: 55.1941
# Iteration : 6000, Cost: 55.0391
# Iteration : 7000, Cost: 54.8848
# Iteration : 8000, Cost: 54.7309
# Iteration : 9000, Cost: 54.5777

# %%
print(f"best beta : {beta}")
# Out:
# best beta : [-0.67974484  0.92444145]

# %%
print(f"final cost : {cost_history[-1]}")
# Out:
# final cost : 54.4251300987735

# %%
y_hat = X_with_bias.dot(beta)
y_hat
# Out:
# array([39.71834645, 87.69685762, 69.48536109, 21.50684992, 80.67110262,
#        89.26840808, 23.81795354, 52.19830601, 44.52544199, 32.78503559,
#        59.50139345, 20.21263189, 32.87747974, 46.46676903, 51.3663087 ,
#        14.01887419, 88.89863151, 16.69975439, 49.79475824, 84.18398012,
#        63.66137997, 34.54147434, 23.91039769, 89.26840808, 86.77241617,
#        24.83483914, 35.65080408, 31.12104099, 38.23924014, 31.95303829,
#        90.65507026, 25.11217157,  9.02689037, 67.35914576, 69.20802866,
#        72.72090616, 14.75842735, 36.11302481, 13.8339859 , 61.62760878,
#        67.91381063, 71.88890886, 55.24896279, 72.72090616, 49.60986995,
#        52.01341772, 44.15566541, 10.69088498, 61.53516464, 34.72636263,
#        84.09153597, 29.27215809, 42.67655909, 85.94041887, 61.2578322 ,
#        81.04087919, 82.79731795, 53.40007989, 75.77156294, 76.60356024,
#         9.11933452, 51.08897627, 43.3236681 , 87.04974861, 35.46591579,
#        51.73608528, 67.08181333, 38.79390501, 89.45329637, 32.23037072,
#        11.61532643, 50.34942311])

# %%
plt.plot(cost_history)
plt.xlabel('Iterations')
plt.ylabel('Cost')
plt.title('Cost Function History')
plt.show()

# %%
x_min, x_max = float(np.min(X)), float(np.max(X)) # get min and max values of X for plotting
x_interval = np.linspace(x_min, x_max, 100) # create an interval of X values for plotting the regression line
x_interval_with_bias = np.column_stack([np.ones((len(x_interval))), x_interval]) # add bias term to the interval X values
y_hat_interval = x_interval_with_bias.dot(beta) # calculate predicted Y values for the interval X values
y_hat_interval
# Out:
# array([ 9.02689037,  9.85141744, 10.67594451, 11.50047158, 12.32499865,
#        13.14952572, 13.97405279, 14.79857986, 15.62310693, 16.447634  ,
#        17.27216107, 18.09668814, 18.92121521, 19.74574227, 20.57026934,
#        21.39479641, 22.21932348, 23.04385055, 23.86837762, 24.69290469,
#        25.51743176, 26.34195883, 27.1664859 , 27.99101297, 28.81554004,
#        29.64006711, 30.46459418, 31.28912125, 32.11364832, 32.93817539,
#        33.76270246, 34.58722953, 35.4117566 , 36.23628367, 37.06081074,
#        37.88533781, 38.70986487, 39.53439194, 40.35891901, 41.18344608,
#        42.00797315, 42.83250022, 43.65702729, 44.48155436, 45.30608143,
#        46.1306085 , 46.95513557, 47.77966264, 48.60418971, 49.42871678,
#        50.25324385, 51.07777092, 51.90229799, 52.72682506, 53.55135213,
#        54.3758792 , 55.20040627, 56.02493334, 56.84946041, 57.67398747,
#        58.49851454, 59.32304161, 60.14756868, 60.97209575, 61.79662282,
#        62.62114989, 63.44567696, 64.27020403, 65.0947311 , 65.91925817,
#        66.74378524, 67.56831231, 68.39283938, 69.21736645, 70.04189352,
#        70.86642059, 71.69094766, 72.51547473, 73.3400018 , 74.16452887,
#        74.98905594, 75.81358301, 76.63811007, 77.46263714, 78.28716421,
#        79.11169128, 79.93621835, 80.76074542, 81.58527249, 82.40979956,
#        83.23432663, 84.0588537 , 84.88338077, 85.70790784, 86.53243491,
#        87.35696198, 88.18148905, 89.00601612, 89.83054319, 90.65507026])

# %%
plt.figure(figsize=(12, 7))

plt.scatter(X, Y)
plt.plot(x_interval, y_hat_interval, 'r--', label="fitted line")
plt.show()
