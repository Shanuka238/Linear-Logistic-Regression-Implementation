# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("zuu crew scores.csv")
df.head()
# Out:
#                        MemberName  EducationLevel  Attendance  TotalHours  \
# 0           Theekshana Rathnayake               3        79.9        43.7
# 1  Mayura Sandakalum Sellapperuma               2        76.8        95.6
# 2                 Amila Narangoda               3        96.6        75.9
# 3                    Nisal Gamage               1        74.5        63.9
# 4                Tharusha Vihanga               2        83.2        24.0
#
#    AssignmentsCompleted  HackathonParticipation  GitHubScore  PeerReviewScore  \
# 0                     2                       0         62.8              5.0
# 1                     6                       0         87.4              2.7
# 2                     8                       0         98.4              2.8
# 3                     7                       0         76.8              1.7
# 4                     6                       0         41.8              4.2
#
#                     CourseName  CapstoneScore
# 0            Foundations of ML           45.3
# 1            Foundations of ML           78.8
# 2            Foundations of ML           65.4
# 3  Production-Ready ML Systems          100.0
# 4            Foundations of ML           40.1

# %%
df = df[df['CourseName'] == 'Foundations of ML']
df.head()
# Out:
#                        MemberName  EducationLevel  Attendance  TotalHours  \
# 0           Theekshana Rathnayake               3        79.9        43.7
# 1  Mayura Sandakalum Sellapperuma               2        76.8        95.6
# 2                 Amila Narangoda               3        96.6        75.9
# 4                Tharusha Vihanga               2        83.2        24.0
# 7                  Chamath Perera               3        86.5        88.0
#
#    AssignmentsCompleted  HackathonParticipation  GitHubScore  PeerReviewScore  \
# 0                     2                       0         62.8              5.0
# 1                     6                       0         87.4              2.7
# 2                     8                       0         98.4              2.8
# 4                     6                       0         41.8              4.2
# 7                     5                       0         23.9              1.3
#
#           CourseName  CapstoneScore
# 0  Foundations of ML           45.3
# 1  Foundations of ML           78.8
# 2  Foundations of ML           65.4
# 4  Foundations of ML           40.1
# 7  Foundations of ML           68.2

# %%
X = df['TotalHours'].values.reshape(-1, 1)
Y = df['CapstoneScore'].values

# %%
plt.figure(figsize=(10,6))
plt.scatter(X, Y, alpha=0.7, color='blue', s=50)
plt.xlabel('GitHubScore')
plt.ylabel('CapstoneScore')
plt.title('GitHubScore vs CapstoneScore')
plt.show()

# %%
def compute_cost(X, Y, beta):
    m = len(Y)
    y_hat = X.dot(beta)
    cost = (1/(2*m)) * np.sum((y_hat - Y) ** 2)

    return cost

# %%
X_with_bias = np.column_stack([np.ones((len(X))), X])
X_with_bias
# Out:
# array([[ 1. , 43.7],
#        [ 1. , 95.6],
#        [ 1. , 75.9],
#        [ 1. , 24. ],
#        [ 1. , 88. ],
#        [ 1. , 97.3],
#        [ 1. , 26.5],
#        [ 1. , 57.2],
#        [ 1. , 48.9],
#        [ 1. , 36.2],
#        [ 1. , 65.1],
#        [ 1. , 22.6],
#        [ 1. , 36.3],
#        [ 1. , 51. ],
#        [ 1. , 56.3],
#        [ 1. , 15.9],
#        [ 1. , 96.9],
#        [ 1. , 18.8],
#        [ 1. , 54.6],
#        [ 1. , 91.8],
#        [ 1. , 69.6],
#        [ 1. , 38.1],
#        [ 1. , 26.6],
#        [ 1. , 97.3],
#        [ 1. , 94.6],
#        [ 1. , 27.6],
#        [ 1. , 39.3],
#        [ 1. , 34.4],
#        [ 1. , 42.1],
#        [ 1. , 35.3],
#        [ 1. , 98.8],
#        [ 1. , 27.9],
#        [ 1. , 10.5],
#        [ 1. , 73.6],
#        [ 1. , 75.6],
#        [ 1. , 79.4],
#        [ 1. , 16.7],
#        [ 1. , 39.8],
#        [ 1. , 15.7],
#        [ 1. , 67.4],
#        [ 1. , 74.2],
#        [ 1. , 78.5],
#        [ 1. , 60.5],
#        [ 1. , 79.4],
#        [ 1. , 54.4],
#        [ 1. , 57. ],
#        [ 1. , 48.5],
#        [ 1. , 12.3],
#        [ 1. , 67.3],
#        [ 1. , 38.3],
#        [ 1. , 91.7],
#        [ 1. , 32.4],
#        [ 1. , 46.9],
#        [ 1. , 93.7],
#        [ 1. , 67. ],
#        [ 1. , 88.4],
#        [ 1. , 90.3],
#        [ 1. , 58.5],
#        [ 1. , 82.7],
#        [ 1. , 83.6],
#        [ 1. , 10.6],
#        [ 1. , 56. ],
#        [ 1. , 47.6],
#        [ 1. , 94.9],
#        [ 1. , 39.1],
#        [ 1. , 56.7],
#        [ 1. , 73.3],
#        [ 1. , 42.7],
#        [ 1. , 97.5],
#        [ 1. , 35.6],
#        [ 1. , 13.3],
#        [ 1. , 55.2]])

# %%
beta = np.random.randn(2)
print(f"Initial beta parameters: {beta}")
# Out:
# Initial beta parameters: [ 0.08863644 -1.3048935 ]

# %%
y_hat = X_with_bias.dot(beta)
y_hat
# Out:
# array([ -56.93520937, -124.65918185,  -98.95277997,  -31.22880748,
#        -114.74199128, -126.8775008 ,  -34.49104122,  -74.55127158,
#         -63.72065555,  -47.14850814,  -84.8599302 ,  -29.40195659,
#         -47.27899749,  -66.4609319 ,  -73.37686743,  -20.65917016,
#        -126.3555434 ,  -24.4433613 ,  -71.15854848, -119.70058657,
#         -90.73195094,  -49.62780579,  -34.62153057, -126.8775008 ,
#        -123.35428836,  -35.92642407,  -51.19367798,  -44.79969985,
#         -54.84737977,  -45.974104  , -128.83484104,  -36.31789212,
#         -13.61274527,  -95.95152492,  -98.56131192, -103.51990721,
#         -21.70308496,  -51.84612473,  -20.39819146,  -87.86118524,
#         -96.73446102, -102.34550306,  -78.85742012, -103.51990721,
#         -70.89756979,  -74.29029288,  -63.19869815,  -15.96155357,
#         -87.73069589,  -49.88878449, -119.57009722,  -42.18991286,
#         -61.11086856, -122.17988421,  -87.33922785, -115.26394868,
#        -117.74324632,  -76.24763312, -107.82605575, -109.00045989,
#         -13.74323462,  -72.98539938,  -62.02429401, -123.74575641,
#         -50.93269928,  -73.89882483,  -95.56005688,  -55.63031587,
#        -127.1384795 ,  -46.36557205,  -17.26644707,  -71.94148458])

# %%
def MSE(Y, y_hat):
    e_i = Y - y_hat
    return np.mean(e_i ** 2)

def MAE(Y, y_hat):
    e_i = Y - y_hat
    return np.mean(np.abs(e_i))

def R2_Score(Y, y_hat):
    y_mean = np.mean(Y)

    e_i = Y - y_hat
    std_i = Y - y_mean

    E = np.sum(e_i ** 2) / np.sum(std_i ** 2)
    return 1 - E

# %%
mse = MSE(Y, y_hat)
mae = MAE(Y, y_hat)
r2 = R2_Score(Y, y_hat)

print(f"MSE: {mse}")
print(f"MAE: {mae}")
print(f"R2 Score: {r2}")
# Out:
# MSE: 19040.001975311185
# MAE: 128.2568444009113
# R2 Score: -65.63661723844143

# %%
cost = compute_cost(X_with_bias, Y, beta)
print("Initial Cost:", cost)
# Out:
# Initial Cost: 9520.00098765559

# %%
def gradient_descent(X, Y, beta, lr, n_iter):
    m = len(Y)
    cost_history = []

    for i in range(n_iter):
        y_hat = X.dot(beta)

        gradients = (1 / m) * X.T.dot(y_hat - Y)

        beta = beta - lr * gradients

        cost = compute_cost(X, Y, beta)
        cost_history.append(cost)

        if i % 1000 == 0:
            print(f"Iteration : {i}, Cost: {cost:.4f}")

    return beta, cost_history

# %%
lr = 0.00001
n_iter = 10000

beta, cost_history = gradient_descent(X_with_bias, Y, beta, lr, n_iter)
# Out:
# Iteration : 0, Cost: 8804.9898
# Iteration : 1000, Cost: 51.2157
# Iteration : 2000, Cost: 51.0751
# Iteration : 3000, Cost: 50.9351
# Iteration : 4000, Cost: 50.7956
# Iteration : 5000, Cost: 50.6566
# Iteration : 6000, Cost: 50.5181
# Iteration : 7000, Cost: 50.3801
# Iteration : 8000, Cost: 50.2426
# Iteration : 9000, Cost: 50.1057

# %%
print(f"best beta : {beta}")
# Out:
# best beta : [0.4934273  0.90733362]

# %%
print(f"final cost : {cost_history[-1]}")
# Out:
# final cost : 49.96929138028577

# %%
y_hat = X_with_bias.dot(beta)
y_hat
# Out:
# array([40.14390668, 87.23452178, 69.36004938, 22.26943428, 80.33878624,
#        88.77698894, 24.53776834, 52.39291061, 44.86204153, 33.3389045 ,
#        59.56084624, 20.99916721, 33.42963786, 46.76744214, 51.57631035,
#        14.92003192, 88.41405549, 17.55129943, 50.03384318, 83.78665401,
#        63.64384755, 35.06283838, 24.6285017 , 88.77698894, 86.32718816,
#        25.53583533, 36.15163873, 31.70570397, 38.69217288, 32.52230424,
#        90.13798938, 25.80803542, 10.02043035, 67.27318205, 69.0878493 ,
#        72.53571707, 15.64589882, 36.60530554, 14.7385652 , 61.64771358,
#        67.81758222, 71.71911681, 55.38711157, 72.53571707, 49.85237646,
#        52.21144388, 44.49910808, 11.65363088, 61.55698021, 35.24430511,
#        83.69592065, 29.89103672, 43.04737428, 85.5105879 , 61.28478013,
#        80.70171969, 82.42565357, 53.57244432, 75.52991803, 76.34651829,
#        10.11116371, 51.30411026, 43.68250781, 86.59938825, 35.97017201,
#        51.9392438 , 67.00098196, 39.23657306, 88.95845567, 32.79450432,
#        12.5609645 , 50.57824336])

# %%
plt.plot(cost_history)
plt.xlabel('Iterations')
plt.ylabel('Cost')
plt.title('Cost Function History')
plt.show()

# %%
x_min, x_max = float(np.min(X)), float(np.max(X)) # get min and max values of X for plotting
x_interval = np.linspace(x_min, x_max, 100) # create an interval of X values for plotting the regression line
x_interval_with_bias = np.column_stack([np.ones((len(x_interval))), x_interval]) # add bias term to the interval X values
y_hat_interval = x_interval_with_bias.dot(beta) # calculate predicted Y values for the interval X values
y_hat_interval
# Out:
# array([10.02043035, 10.82969862, 11.6389669 , 12.44823517, 13.25750344,
#        14.06677172, 14.87603999, 15.68530826, 16.49457654, 17.30384481,
#        18.11311308, 18.92238135, 19.73164963, 20.5409179 , 21.35018617,
#        22.15945445, 22.96872272, 23.77799099, 24.58725927, 25.39652754,
#        26.20579581, 27.01506409, 27.82433236, 28.63360063, 29.4428689 ,
#        30.25213718, 31.06140545, 31.87067372, 32.679942  , 33.48921027,
#        34.29847854, 35.10774682, 35.91701509, 36.72628336, 37.53555163,
#        38.34481991, 39.15408818, 39.96335645, 40.77262473, 41.581893  ,
#        42.39116127, 43.20042955, 44.00969782, 44.81896609, 45.62823436,
#        46.43750264, 47.24677091, 48.05603918, 48.86530746, 49.67457573,
#        50.483844  , 51.29311228, 52.10238055, 52.91164882, 53.72091709,
#        54.53018537, 55.33945364, 56.14872191, 56.95799019, 57.76725846,
#        58.57652673, 59.38579501, 60.19506328, 61.00433155, 61.81359982,
#        62.6228681 , 63.43213637, 64.24140464, 65.05067292, 65.85994119,
#        66.66920946, 67.47847774, 68.28774601, 69.09701428, 69.90628256,
#        70.71555083, 71.5248191 , 72.33408737, 73.14335565, 73.95262392,
#        74.76189219, 75.57116047, 76.38042874, 77.18969701, 77.99896529,
#        78.80823356, 79.61750183, 80.4267701 , 81.23603838, 82.04530665,
#        82.85457492, 83.6638432 , 84.47311147, 85.28237974, 86.09164802,
#        86.90091629, 87.71018456, 88.51945283, 89.32872111, 90.13798938])

# %%
plt.figure(figsize=(12, 7))

plt.scatter(X, Y)
plt.plot(x_interval, y_hat_interval, 'r--', label="fitted line")
plt.show()

# %%
def MSE(Y, y_hat):
    e_i = Y - y_hat
    return np.mean(e_i ** 2)

def MAE(Y, y_hat):
    e_i = Y - y_hat
    return np.mean(np.abs(e_i))

def R2_Score(Y, y_hat):
    y_mean = np.mean(Y)

    e_i = Y - y_hat
    std_i = Y - y_mean

    E = np.sum(e_i ** 2) / np.sum(std_i ** 2)
    return 1 - E

# %%
mse = MSE(Y, y_hat)
mae = MAE(Y, y_hat)
r2 = R2_Score(Y, y_hat)

print(f"MSE: {mse}")
print(f"MAE: {mae}")
print(f"R2 Score: {r2}")
# Out:
# MSE: 99.93858276057153
# MAE: 8.233010507919564
# R2 Score: 0.6502327523177862
