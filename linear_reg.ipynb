# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("zuu crew scores.csv")
df.head()
# Out:
#                        MemberName  EducationLevel  Attendance  TotalHours  \
# 0           Theekshana Rathnayake               3        79.9        43.7
# 1  Mayura Sandakalum Sellapperuma               2        76.8        95.6
# 2                 Amila Narangoda               3        96.6        75.9
# 3                    Nisal Gamage               1        74.5        63.9
# 4                Tharusha Vihanga               2        83.2        24.0
#
#    AssignmentsCompleted  HackathonParticipation  GitHubScore  PeerReviewScore  \
# 0                     2                       0         62.8              5.0
# 1                     6                       0         87.4              2.7
# 2                     8                       0         98.4              2.8
# 3                     7                       0         76.8              1.7
# 4                     6                       0         41.8              4.2
#
#                     CourseName  CapstoneScore
# 0            Foundations of ML           45.3
# 1            Foundations of ML           78.8
# 2            Foundations of ML           65.4
# 3  Production-Ready ML Systems          100.0
# 4            Foundations of ML           40.1

# %%
df = df[df['CourseName'] == 'Foundations of ML']
df.head()
# Out:
#                        MemberName  EducationLevel  Attendance  TotalHours  \
# 0           Theekshana Rathnayake               3        79.9        43.7
# 1  Mayura Sandakalum Sellapperuma               2        76.8        95.6
# 2                 Amila Narangoda               3        96.6        75.9
# 4                Tharusha Vihanga               2        83.2        24.0
# 7                  Chamath Perera               3        86.5        88.0
#
#    AssignmentsCompleted  HackathonParticipation  GitHubScore  PeerReviewScore  \
# 0                     2                       0         62.8              5.0
# 1                     6                       0         87.4              2.7
# 2                     8                       0         98.4              2.8
# 4                     6                       0         41.8              4.2
# 7                     5                       0         23.9              1.3
#
#           CourseName  CapstoneScore
# 0  Foundations of ML           45.3
# 1  Foundations of ML           78.8
# 2  Foundations of ML           65.4
# 4  Foundations of ML           40.1
# 7  Foundations of ML           68.2

# %%
X = df['TotalHours'].values.reshape(-1, 1)
Y = df['CapstoneScore'].values

# %%
plt.figure(figsize=(10,6))
plt.scatter(X, Y, alpha=0.7, color='blue', s=50)
plt.xlabel('GitHubScore')
plt.ylabel('CapstoneScore')
plt.title('GitHubScore vs CapstoneScore')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[581], line 2
#       1 plt.figure(figsize=(10,6))
# ----> 2 plt.scatter(X, Y, alpha=0.7, color='blue', s=50)
#       3 plt.xlabel('GitHubScore')
#       4 plt.ylabel('CapstoneScore')
#
# File c:\Users\User\anaconda3\envs\foml\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File c:\Users\User\anaconda3\envs\foml\Lib\site-packages\matplotlib\pyplot.py:3948, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, colorizer, plotnonfinite, data, **kwargs)
#    3928 @_copy_docstring_and_deprecators(Axes.scatter)
#    3929 def scatter(
#    3930     x: float | ArrayLike,
#    (...)   3946     **kwargs,
#    3947 ) -> PathCollection:
# -> 3948     __ret = gca().scatter(
#    3949         x,
#    3950         y,
#    3951         s=s,
#    3952         c=c,
#    3953         marker=marker,
#    3954         cmap=cmap,
#    3955         norm=norm,
#    3956         vmin=vmin,
#    3957         vmax=vmax,
#    3958         alpha=alpha,
#    3959         linewidths=linewidths,
#    3960         edgecolors=edgecolors,
#    3961         colorizer=colorizer,
#    3962         plotnonfinite=plotnonfinite,
#    3963         **({"data": data} if data is not None else {}),
#    3964         **kwargs,
#    3965     )
#    3966     sci(__ret)
#    3967     return __ret
#
# File c:\Users\User\anaconda3\envs\foml\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File c:\Users\User\anaconda3\envs\foml\Lib\site-packages\matplotlib\__init__.py:1524, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1521 @functools.wraps(func)
#    1522 def inner(ax, *args, data=None, **kwargs):
#    1523     if data is None:
# -> 1524         return func(
#    1525             ax,
#    1526             *map(cbook.sanitize_sequence, args),
#    1527             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1529     bound = new_sig.bind(ax, *args, **kwargs)
#    1530     auto_label = (bound.arguments.get(label_namer)
#    1531                   or bound.kwargs.get(label_namer))
#
# File c:\Users\User\anaconda3\envs\foml\Lib\site-packages\matplotlib\axes\_axes.py:4936, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, colorizer, plotnonfinite, **kwargs)
#    4934 y = np.ma.ravel(y)
#    4935 if x.size != y.size:
# -> 4936     raise ValueError("x and y must be the same size")
#    4938 if s is None:
#    4939     s = (20 if mpl.rcParams['_internal.classic_mode'] else
#    4940          mpl.rcParams['lines.markersize'] ** 2.0)
#
# ValueError: x and y must be the same size

# %%
def compute_cost(X, Y, beta):
    m = len(Y)
    y_hat = X.dot(beta)
    cost = (1/(2*m)) * np.sum((y_hat - Y) ** 2)

    return cost

# %%
X_with_bias = np.column_stack([np.ones((len(X))), X])
X_with_bias
# Out:
# array([[ 1. , 43.7],
#        [ 1. , 95.6],
#        [ 1. , 75.9],
#        [ 1. , 24. ],
#        [ 1. , 88. ],
#        [ 1. , 97.3],
#        [ 1. , 26.5],
#        [ 1. , 57.2],
#        [ 1. , 48.9],
#        [ 1. , 36.2],
#        [ 1. , 65.1],
#        [ 1. , 22.6],
#        [ 1. , 36.3],
#        [ 1. , 51. ],
#        [ 1. , 56.3],
#        [ 1. , 15.9],
#        [ 1. , 96.9],
#        [ 1. , 18.8],
#        [ 1. , 54.6],
#        [ 1. , 91.8],
#        [ 1. , 69.6],
#        [ 1. , 38.1],
#        [ 1. , 26.6],
#        [ 1. , 97.3],
#        [ 1. , 94.6],
#        [ 1. , 27.6],
#        [ 1. , 39.3],
#        [ 1. , 34.4],
#        [ 1. , 42.1],
#        [ 1. , 35.3],
#        [ 1. , 98.8],
#        [ 1. , 27.9],
#        [ 1. , 10.5],
#        [ 1. , 73.6],
#        [ 1. , 75.6],
#        [ 1. , 79.4],
#        [ 1. , 16.7],
#        [ 1. , 39.8],
#        [ 1. , 15.7],
#        [ 1. , 67.4],
#        [ 1. , 74.2],
#        [ 1. , 78.5],
#        [ 1. , 60.5],
#        [ 1. , 79.4],
#        [ 1. , 54.4],
#        [ 1. , 57. ],
#        [ 1. , 48.5],
#        [ 1. , 12.3],
#        [ 1. , 67.3],
#        [ 1. , 38.3],
#        [ 1. , 91.7],
#        [ 1. , 32.4],
#        [ 1. , 46.9],
#        [ 1. , 93.7],
#        [ 1. , 67. ],
#        [ 1. , 88.4],
#        [ 1. , 90.3],
#        [ 1. , 58.5],
#        [ 1. , 82.7],
#        [ 1. , 83.6],
#        [ 1. , 10.6],
#        [ 1. , 56. ],
#        [ 1. , 47.6],
#        [ 1. , 94.9],
#        [ 1. , 39.1],
#        [ 1. , 56.7],
#        [ 1. , 73.3],
#        [ 1. , 42.7],
#        [ 1. , 97.5],
#        [ 1. , 35.6],
#        [ 1. , 13.3],
#        [ 1. , 55.2]])

# %%
beta = np.random.randn(2)
print(f"Initial beta parameters: {beta}")
# Out:
# Initial beta parameters: [ 0.6580292  -0.73352081]

# %%
y_hat = X_with_bias.dot(beta)
y_hat
# Out:
# array([-31.39683008, -69.46655998, -55.01620007, -16.94647017,
#        -63.89180184, -70.71354535, -18.78027219, -41.29936098,
#        -35.21113828, -25.89542402, -47.09417535, -15.91954104,
#        -25.9687761 , -36.75153197, -40.63919225, -11.00495164,
#        -70.42013703, -13.13216198, -39.39220688, -66.67918091,
#        -50.39501899, -27.28911356, -18.85362427, -70.71354535,
#        -68.73303917, -19.58714508, -28.16933853, -24.57508657,
#        -30.22319679, -25.2352553 , -71.81382656, -19.80720132,
#         -7.04393928, -53.32910222, -54.79614383, -57.5835229 ,
#        -11.59176828, -28.53609893, -10.85824747, -48.78127321,
#        -53.7692147 , -56.92335417, -43.71997964, -57.5835229 ,
#        -39.24550272, -41.15265682, -34.91772995,  -8.36427673,
#        -48.70792113, -27.43581772, -66.60582883, -23.10804496,
#        -33.74409666, -68.07287044, -48.48786489, -64.18521016,
#        -65.5788997 , -42.25293803, -60.00414156, -60.66431029,
#         -7.11729136, -40.41913601, -34.25756123, -68.95309541,
#        -28.02263437, -40.93260057, -53.10904597, -30.66330927,
#        -70.86024951, -25.45531154,  -9.09779754, -39.83231936])

# %%
cost = compute_cost(X_with_bias, Y, beta)
print("Initial Cost:", cost)
# Out:
# Initial Cost: 5215.609434101753

# %%
def gradient_descent(X, Y, beta, lr, n_iter):
    m = len(Y)
    cost_history = []

    for i in range(n_iter):
        y_hat = X.dot(beta)

        gradients = (1 / m) * X.T.dot(y_hat - Y)

        beta = beta - lr * gradients

        cost = compute_cost(X, Y, beta)
        cost_history.append(cost)

        if i % 1000 == 0:
            print(f"Iteration : {i}, Cost: {cost:.4f}")

    return beta, cost_history

# %%
lr = 0.00001
n_iter = 10000

beta, cost_history = gradient_descent(X_with_bias, Y, beta, lr, n_iter)
# Out:
# Iteration : 0, Cost: 4825.4811
# Iteration : 1000, Cost: 49.1431
# Iteration : 2000, Cost: 49.0101
# Iteration : 3000, Cost: 48.8775
# Iteration : 4000, Cost: 48.7455
# Iteration : 5000, Cost: 48.6139
# Iteration : 6000, Cost: 48.4828
# Iteration : 7000, Cost: 48.3522
# Iteration : 8000, Cost: 48.2221
# Iteration : 9000, Cost: 48.0924

# %%
print(f"best beta : {beta}")
# Out:
# best beta : [1.04427641 0.89930085]

# %%
print(f"final cost : {cost_history[-1]}")
# Out:
# final cost : 47.963332571164344

# %%
y_hat = X_with_bias.dot(beta)
y_hat
# Out:
# array([40.34372345, 87.01743745, 69.30121075, 22.62749675, 80.18275101,
#        88.54624889, 24.87574887, 52.4842849 , 45.02008786, 33.5989671 ,
#        59.5887616 , 21.36847557, 33.68889718, 46.90861964, 51.67491414,
#        15.34315989, 88.18652855, 17.95113235, 50.14610269, 83.60009423,
#        63.63561541, 35.30763871, 24.96567896, 88.54624889, 86.1181366 ,
#        25.86497981, 36.38679972, 31.98022557, 38.9048421 , 32.78959633,
#        89.89520017, 26.13477006, 10.48693531, 67.2328188 , 69.0314205 ,
#        72.44876372, 16.06260057, 36.83645015, 15.16329972, 61.65715355,
#        67.77239931, 71.63939296, 55.4519777 , 72.44876372, 49.96624253,
#        52.30442473, 44.66036752, 12.10567684, 61.56722346, 35.48749888,
#        83.51016415, 30.18162387, 43.22148617, 85.30876584, 61.29743321,
#        80.54247135, 82.25114296, 53.653376  , 75.41645652, 76.22582728,
#        10.57686539, 51.40512388, 43.85099676, 86.38792686, 36.20693955,
#        52.03463448, 66.96302855, 39.44442261, 88.72610906, 33.05938659,
#        13.00497768, 50.6856832 ])

# %%
plt.plot(cost_history)
plt.xlabel('Iterations')
plt.ylabel('Cost')
plt.title('Cost Function History')
plt.show()

# %%
x_min, x_max = float(np.min(X)), float(np.max(X)) # get min and max values of X for plotting
x_interval = np.linspace(x_min, x_max, 100) # create an interval of X values for plotting the regression line
x_interval_with_bias = np.column_stack([np.ones((len(x_interval))), x_interval]) # add bias term to the interval X values
y_hat_interval = x_interval_with_bias.dot(beta) # calculate predicted Y values for the interval X values
y_hat_interval
# Out:
# array([10.48693531, 11.28903899, 12.09114268, 12.89324637, 13.69535005,
#        14.49745374, 15.29955742, 16.10166111, 16.90376479, 17.70586848,
#        18.50797216, 19.31007585, 20.11217953, 20.91428322, 21.71638691,
#        22.51849059, 23.32059428, 24.12269796, 24.92480165, 25.72690533,
#        26.52900902, 27.3311127 , 28.13321639, 28.93532007, 29.73742376,
#        30.53952744, 31.34163113, 32.14373482, 32.9458385 , 33.74794219,
#        34.55004587, 35.35214956, 36.15425324, 36.95635693, 37.75846061,
#        38.5605643 , 39.36266798, 40.16477167, 40.96687536, 41.76897904,
#        42.57108273, 43.37318641, 44.1752901 , 44.97739378, 45.77949747,
#        46.58160115, 47.38370484, 48.18580852, 48.98791221, 49.79001589,
#        50.59211958, 51.39422327, 52.19632695, 52.99843064, 53.80053432,
#        54.60263801, 55.40474169, 56.20684538, 57.00894906, 57.81105275,
#        58.61315643, 59.41526012, 60.2173638 , 61.01946749, 61.82157118,
#        62.62367486, 63.42577855, 64.22788223, 65.02998592, 65.8320896 ,
#        66.63419329, 67.43629697, 68.23840066, 69.04050434, 69.84260803,
#        70.64471172, 71.4468154 , 72.24891909, 73.05102277, 73.85312646,
#        74.65523014, 75.45733383, 76.25943751, 77.0615412 , 77.86364488,
#        78.66574857, 79.46785225, 80.26995594, 81.07205963, 81.87416331,
#        82.676267  , 83.47837068, 84.28047437, 85.08257805, 85.88468174,
#        86.68678542, 87.48888911, 88.29099279, 89.09309648, 89.89520017])

# %%
plt.figure(figsize=(12, 7))

plt.scatter(X, Y)
plt.plot(x_interval, y_hat_interval, 'r--', label="fitted line")
plt.show()
